# %%
import pandas as pd

# %%
df=pd.read_html("https://www.worldometers.info/world-population/india-population/")[1]
df
# Out:
#     Year  Population Yearly % Change  Yearly  Change  Migrants (net)  \
# 0   2023  1428627663          0.81 %        11454490         -486136
# 1   2022  1417173173          0.68 %         9609331         -487303
# 2   2020  1396387127          0.96 %        13275077          -34772
# 3   2015  1322866505          1.29 %        16450577         -475094
# 4   2010  1240613620          1.45 %        17194981         -380087
# 5   2005  1154638713          1.73 %        19001008         -550186
# 6   2000  1059633675          1.90 %        19070909         -149966
# 7   1995   964279129          2.07 %        18765393          -57139
# 8   1990   870452165          2.21 %        18042016          108465
# 9   1985   780242084          2.29 %        16682740         -112781
# 10  1980   696828385          2.25 %        14660833          202323
# 11  1975   623524219          2.26 %        13204584         -225989
# 12  1970   557501301          2.20 %        11477391          -45792
# ...

# %%
import seaborn as sns

# %%
fig,ax=plt.subplots(figsize=(10,6))
ax.set_xticklabels(ax.get_xticklabels(),rotation=40);
plt.tight_layout()
g=sns.barplot(data=df,x="Year",y="Population",palette="husl")
g.set_title("Population per Year")
# Out:
# C:\Users\mridu\AppData\Local\Temp\ipykernel_720\2183010966.py:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=40);
